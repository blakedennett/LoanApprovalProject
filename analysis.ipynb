# %%
import pandas as pd
from scipy.stats import pearsonr

# %% [markdown]
# ##### Load the Data

# %%
df = pd.read_csv(r'C:\Users\Blake Dennett\Downloads\Summer2023\loan_approval_dataset.csv')
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 0                  17600000              22700000            8000000
# 1                   2200000               8800000            3300000
# 2                   4500000              33300000           12800000
# 3                   3300000              23300000            7900000
# 4                   8200000              29400000            5000000
#
#    loan_status
# 0     Approved
# 1     Rejected
# 2     Rejected
# 3     Rejected
# 4     Rejected

# %%
df.describe()
# Out:
#            loan_id   no_of_dependents   income_annum   loan_amount  \
# count  4269.000000        4269.000000   4.269000e+03  4.269000e+03
# mean   2135.000000           2.498712   5.059124e+06  1.513345e+07
# std    1232.498479           1.695910   2.806840e+06  9.043363e+06
# min       1.000000           0.000000   2.000000e+05  3.000000e+05
# 25%    1068.000000           1.000000   2.700000e+06  7.700000e+06
# 50%    2135.000000           3.000000   5.100000e+06  1.450000e+07
# 75%    3202.000000           4.000000   7.500000e+06  2.150000e+07
# max    4269.000000           5.000000   9.900000e+06  3.950000e+07
#
#          loan_term   cibil_score   residential_assets_value  \
# count  4269.000000   4269.000000               4.269000e+03
# mean     10.900445    599.936051               7.472617e+06
# std       5.709187    172.430401               6.503637e+06
# min       2.000000    300.000000              -1.000000e+05
# 25%       6.000000    453.000000               2.200000e+06
# 50%      10.000000    600.000000               5.600000e+06
# 75%      16.000000    748.000000               1.130000e+07
# max      20.000000    900.000000               2.910000e+07
#
#         commercial_assets_value   luxury_assets_value   bank_asset_value
# count              4.269000e+03          4.269000e+03       4.269000e+03
# mean               4.973155e+06          1.512631e+07       4.976692e+06
# std                4.388966e+06          9.103754e+06       3.250185e+06
# min                0.000000e+00          3.000000e+05       0.000000e+00
# 25%                1.300000e+06          7.500000e+06       2.300000e+06
# 50%                3.700000e+06          1.460000e+07       4.600000e+06
# 75%                7.600000e+06          2.170000e+07       7.100000e+06
# max                1.940000e+07          3.920000e+07       1.470000e+07

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ##### Check for any missing values in the data

# %%
df.isna().any()
# no missing values
# Out:
# loan_id                      False
#  no_of_dependents            False
#  education                   False
#  self_employed               False
#  income_annum                False
#  loan_amount                 False
#  loan_term                   False
#  cibil_score                 False
#  residential_assets_value    False
#  commercial_assets_value     False
#  luxury_assets_value         False
#  bank_asset_value            False
#  loan_status                 False
# dtype: bool

# %% [markdown]
# ##### Check categorical features

# %%
print(df[' loan_status'].value_counts())
print()
print(df[' self_employed'].value_counts())
print()
df[' education'].value_counts()
# no issues found
# Out:
#  Approved    2656
#  Rejected    1613
# Name:  loan_status, dtype: int64
#
#  Yes    2150
#  No     2119
# Name:  self_employed, dtype: int64
#  Graduate        2144
#  Not Graduate    2125
# Name:  education, dtype: int64

# %% [markdown]
# ##### Check for values outside of 3 standard deviations

# %%
numerical_df = df.drop(columns=[' loan_status', ' education', ' self_employed'])

std_factor = 3

stdv_df = numerical_df.std()   # creates a series of standard deviations for each column
avg_df = numerical_df.mean()

upper_limits = avg_df + std_factor * stdv_df     # creates a series of upper limits for each column
lower_limits = avg_df - std_factor * stdv_df

numerical_cols = numerical_df.columns

# Create a condition for numeric columns only
condition = (numerical_df[numerical_cols] > upper_limits) | (numerical_df[numerical_cols] < lower_limits)

# Update the values in the original DataFrame 'df' with the capped values
df[numerical_cols] = df[numerical_cols].where(~condition, other=upper_limits, axis=0)

# count the number of capped values
count = condition.sum().sum()

print(count)

# there were 33 outliers in the numerical data, about half of which were residential assets, the other were commercial assets
# the outliers were replaced with the upper limit of the data
# Out:
# 33

# %% [markdown]
# ##### Checking for inappropriate negative values

# %%
numerical_df = df.drop(columns=[' loan_status', ' education', ' self_employed'])
numerical_cols = numerical_df.columns

count = 0
for col in numerical_df.columns:
    for row in numerical_df.iterrows():
        if row[1][col] < 0:
            print(row)
            count += 1

df[numerical_cols] = df[numerical_cols].applymap(lambda x: x if x >= 0 else 0)

print(count)

# there were 28 instances of a negative value and all were in the residential asset column, and they were all the exact same value 
# so I am just going to change them all to 0
# Out:
# (59, loan_id                            60.0
#  no_of_dependents                   4.0
#  income_annum                 5500000.0
#  loan_amount                 18200000.0
#  loan_term                         16.0
#  cibil_score                      797.0
#  residential_assets_value     -100000.0
#  commercial_assets_value      4900000.0
#  luxury_assets_value         18600000.0
#  bank_asset_value             4800000.0
# Name: 59, dtype: float64)
# (196, loan_id                          197.0
#  no_of_dependents                  4.0
#  income_annum                 400000.0
#  loan_amount                 1500000.0
#  loan_term                         2.0
#  cibil_score                     669.0
#  residential_assets_value    -100000.0
#  commercial_assets_value      600000.0
#  luxury_assets_value          900000.0
#  bank_asset_value             500000.0
# Name: 196, dtype: float64)
# (559, loan_id                         560.0
#  no_of_dependents                 2.0
#  income_annum                200000.0
#  loan_amount                 500000.0
#  loan_term                        6.0
#  cibil_score                    885.0
#  residential_assets_value   -100000.0
#  commercial_assets_value          0.0
#  luxury_assets_value         300000.0
#  bank_asset_value            200000.0
# Name: 559, dtype: float64)
# (702, loan_id                           703.0
#  no_of_dependents                   4.0
#  income_annum                 6300000.0
#  loan_amount                 23900000.0
#  loan_term                          6.0
#  cibil_score                      899.0
#  residential_assets_value     -100000.0
#  commercial_assets_value     11400000.0
#  luxury_assets_value         20600000.0
#  bank_asset_value             6700000.0
# Name: 702, dtype: float64)
# (737, loan_id                          738.0
#  no_of_dependents                  2.0
#  income_annum                 900000.0
#  loan_amount                 2500000.0
#  loan_term                        16.0
#  cibil_score                     458.0
#  residential_assets_value    -100000.0
#  commercial_assets_value      100000.0
#  luxury_assets_value         3200000.0
#  bank_asset_value            1100000.0
# Name: 737, dtype: float64)
# (784, loan_id                           785.0
#  no_of_dependents                   0.0
#  income_annum                 5000000.0
#  loan_amount                 14400000.0
#  loan_term                          2.0
#  cibil_score                      761.0
#  residential_assets_value     -100000.0
#  commercial_assets_value      7300000.0
#  luxury_assets_value         12600000.0
#  bank_asset_value             4500000.0
# Name: 784, dtype: float64)
# (904, loan_id                           905.0
#  no_of_dependents                   2.0
#  income_annum                 4100000.0
#  loan_amount                 14900000.0
#  loan_term                         12.0
#  cibil_score                      571.0
#  residential_assets_value     -100000.0
#  commercial_assets_value      5200000.0
#  luxury_assets_value         13000000.0
#  bank_asset_value             3400000.0
# Name: 904, dtype: float64)
# (1089, loan_id                          1090.0
#  no_of_dependents                   3.0
#  income_annum                 5100000.0
#  loan_amount                 11000000.0
#  loan_term                          6.0
#  cibil_score                      336.0
#  residential_assets_value     -100000.0
#  commercial_assets_value      5800000.0
#  luxury_assets_value         11600000.0
#  bank_asset_value             7500000.0
# Name: 1089, dtype: float64)
# (1163, loan_id                          1164.0
#  no_of_dependents                   2.0
#  income_annum                 4500000.0
#  loan_amount                  9100000.0
#  loan_term                         18.0
#  cibil_score                      593.0
#  residential_assets_value     -100000.0
#  commercial_assets_value       600000.0
#  luxury_assets_value         12400000.0
#  bank_asset_value             2500000.0
# Name: 1163, dtype: float64)
# (1350, loan_id                          1351.0
#  no_of_dependents                   5.0
#  income_annum                 4000000.0
#  loan_amount                 13700000.0
#  loan_term                          6.0
#  cibil_score                      496.0
#  residential_assets_value     -100000.0
#  commercial_assets_value      1400000.0
#  luxury_assets_value         15800000.0
#  bank_asset_value             3700000.0
# Name: 1350, dtype: float64)
# (1392, loan_id                         1393.0
#  no_of_dependents                  0.0
#  income_annum                 400000.0
#  loan_amount                  900000.0
#  loan_term                         2.0
#  cibil_score                     855.0
#  residential_assets_value    -100000.0
#  commercial_assets_value      500000.0
#  luxury_assets_value         1300000.0
#  bank_asset_value             400000.0
# Name: 1392, dtype: float64)
# (1773, loan_id                          1774.0
#  no_of_dependents                   2.0
#  income_annum                 5500000.0
#  loan_amount                 12400000.0
#  loan_term                         14.0
#  cibil_score                      842.0
#  residential_assets_value     -100000.0
#  commercial_assets_value      6800000.0
#  luxury_assets_value         15800000.0
#  bank_asset_value             5800000.0
# Name: 1773, dtype: float64)
# (1806, loan_id                          1807.0
#  no_of_dependents                   1.0
#  income_annum                 6200000.0
#  loan_amount                 16200000.0
#  loan_term                          4.0
#  cibil_score                      888.0
#  residential_assets_value     -100000.0
#  commercial_assets_value     12000000.0
#  luxury_assets_value         24300000.0
#  bank_asset_value             4000000.0
# Name: 1806, dtype: float64)
# (1866, loan_id                        1867.0
#  no_of_dependents                 5.0
#  income_annum                200000.0
#  loan_amount                 300000.0
#  loan_term                        8.0
#  cibil_score                    412.0
#  residential_assets_value   -100000.0
#  commercial_assets_value     100000.0
#  luxury_assets_value         500000.0
#  bank_asset_value            100000.0
# Name: 1866, dtype: float64)
# (1933, loan_id                         1934.0
#  no_of_dependents                  5.0
#  income_annum                 500000.0
#  loan_amount                 1500000.0
#  loan_term                         6.0
#  cibil_score                     433.0
#  residential_assets_value    -100000.0
#  commercial_assets_value      700000.0
#  luxury_assets_value         1900000.0
#  bank_asset_value             700000.0
# Name: 1933, dtype: float64)
# (1950, loan_id                        1951.0
#  no_of_dependents                 0.0
#  income_annum                200000.0
#  loan_amount                 700000.0
#  loan_term                       10.0
#  cibil_score                    587.0
#  residential_assets_value   -100000.0
#  commercial_assets_value     100000.0
#  luxury_assets_value         500000.0
#  bank_asset_value            100000.0
# Name: 1950, dtype: float64)
# (2707, loan_id                          2708.0
#  no_of_dependents                   2.0
#  income_annum                 7800000.0
#  loan_amount                 29600000.0
#  loan_term                         14.0
#  cibil_score                      568.0
#  residential_assets_value     -100000.0
#  commercial_assets_value      8600000.0
#  luxury_assets_value         27000000.0
#  bank_asset_value             7200000.0
# Name: 2707, dtype: float64)
# (3019, loan_id                        3020.0
#  no_of_dependents                 4.0
#  income_annum                300000.0
#  loan_amount                 600000.0
#  loan_term                        6.0
#  cibil_score                    365.0
#  residential_assets_value   -100000.0
#  commercial_assets_value     400000.0
#  luxury_assets_value         600000.0
#  bank_asset_value            200000.0
# Name: 3019, dtype: float64)
# (3164, loan_id                         3165.0
#  no_of_dependents                  4.0
#  income_annum                2400000.0
#  loan_amount                 8000000.0
#  loan_term                        18.0
#  cibil_score                     393.0
#  residential_assets_value    -100000.0
#  commercial_assets_value      200000.0
#  luxury_assets_value         7600000.0
#  bank_asset_value            3000000.0
# Name: 3164, dtype: float64)
# (3180, loan_id                          3181.0
#  no_of_dependents                   4.0
#  income_annum                 3200000.0
#  loan_amount                 12200000.0
#  loan_term                         14.0
#  cibil_score                      683.0
#  residential_assets_value     -100000.0
#  commercial_assets_value      1100000.0
#  luxury_assets_value          7500000.0
#  bank_asset_value             2900000.0
# Name: 3180, dtype: float64)
# (3431, loan_id                         3432.0
#  no_of_dependents                  4.0
#  income_annum                 400000.0
#  loan_amount                 1400000.0
#  loan_term                        18.0
#  cibil_score                     827.0
#  residential_assets_value    -100000.0
#  commercial_assets_value           0.0
#  luxury_assets_value          900000.0
#  bank_asset_value             600000.0
# Name: 3431, dtype: float64)
# (3730, loan_id                        3731.0
#  no_of_dependents                 5.0
#  income_annum                200000.0
#  loan_amount                 700000.0
#  loan_term                       18.0
#  cibil_score                    707.0
#  residential_assets_value   -100000.0
#  commercial_assets_value     100000.0
#  luxury_assets_value         500000.0
#  bank_asset_value            200000.0
# Name: 3730, dtype: float64)
# (3747, loan_id                         3748.0
#  no_of_dependents                  4.0
#  income_annum                2300000.0
#  loan_amount                 5500000.0
#  loan_term                         6.0
#  cibil_score                     343.0
#  residential_assets_value    -100000.0
#  commercial_assets_value     4100000.0
#  luxury_assets_value         4800000.0
#  bank_asset_value            3200000.0
# Name: 3747, dtype: float64)
# (3962, loan_id                         3963.0
#  no_of_dependents                  3.0
#  income_annum                 500000.0
#  loan_amount                 1900000.0
#  loan_term                        18.0
#  cibil_score                     618.0
#  residential_assets_value    -100000.0
#  commercial_assets_value      600000.0
#  luxury_assets_value         1000000.0
#  bank_asset_value             400000.0
# Name: 3962, dtype: float64)
# (4076, loan_id                         4077.0
#  no_of_dependents                  2.0
#  income_annum                1500000.0
#  loan_amount                 4900000.0
#  loan_term                        16.0
#  cibil_score                     387.0
#  residential_assets_value    -100000.0
#  commercial_assets_value     2400000.0
#  luxury_assets_value         3700000.0
#  bank_asset_value            1300000.0
# Name: 4076, dtype: float64)
# (4130, loan_id                          4131.0
#  no_of_dependents                   0.0
#  income_annum                 6200000.0
#  loan_amount                 14900000.0
#  loan_term                          8.0
#  cibil_score                      855.0
#  residential_assets_value     -100000.0
#  commercial_assets_value      7200000.0
#  luxury_assets_value         14200000.0
#  bank_asset_value             8200000.0
# Name: 4130, dtype: float64)
# (4206, loan_id                         4207.0
#  no_of_dependents                  0.0
#  income_annum                2100000.0
#  loan_amount                 8300000.0
#  loan_term                        20.0
#  cibil_score                     765.0
#  residential_assets_value    -100000.0
#  commercial_assets_value     3600000.0
#  luxury_assets_value         7700000.0
#  bank_asset_value            2100000.0
# Name: 4206, dtype: float64)
# (4243, loan_id                         4244.0
#  no_of_dependents                  0.0
#  income_annum                1600000.0
#  loan_amount                 3400000.0
#  loan_term                         8.0
#  cibil_score                     867.0
#  residential_assets_value    -100000.0
#  commercial_assets_value     2700000.0
#  luxury_assets_value         4300000.0
#  bank_asset_value            1300000.0
# Name: 4243, dtype: float64)
# 28

# %% [markdown]
# # Analysis and Feature Engineering

# %% [markdown]
# ##### Total Collateral

# %%
collateral_df = df[[' residential_assets_value',  ' commercial_assets_value', ' bank_asset_value', ' luxury_assets_value']]
df[' total_collateral'] = collateral_df.apply(lambda x: x.sum(), axis=1)

# %% [markdown]
# ##### Loan Collateral Ratio

# %%
df[' loan_coll_ratio'] = df[' loan_amount'] / df[' total_collateral']
df[' loan_coll_ratio'].describe()
# lower is better
# Out:
# count    4269.000000
# mean        0.488241
# std         0.145773
# min         0.176471
# 25%         0.384217
# 50%         0.467290
# 75%         0.568182
# max         1.333333
# Name:  loan_coll_ratio, dtype: float64

# %% [markdown]
# ##### Loan Amount by Income

# %%
df[' loan_income_ratio'] = df[' loan_amount'] / df[' income_annum']
df[' loan_income_ratio'].describe()
# lower is better
# Out:
# count    4269.000000
# mean        2.984807
# std         0.595496
# min         1.500000
# 25%         2.464286
# 50%         3.000000
# 75%         3.500000
# max         4.000000
# Name:  loan_income_ratio, dtype: float64

# %% [markdown]
# ##### Credit Score Odd Values (See Cibil score graph)

# %%
rejected_df = df[df[' loan_status'] == ' Rejected']

rejec_cibil_above_550 = rejected_df[rejected_df[' cibil_score'] >= 550]

rejec_cibil_above_550

# there are 13 values where the credit score is above 550 and was still rejected
# Out:
#       loan_id   no_of_dependents      education  self_employed   income_annum  \
# 67         68                  0   Not Graduate            Yes        2700000
# 236       237                  3       Graduate            Yes         900000
# 348       349                  0   Not Graduate             No        2000000
# 395       396                  2       Graduate            Yes         800000
# 559       560                  2       Graduate            Yes         200000
# 911       912                  0       Graduate            Yes        1300000
# 1446     1447                  1       Graduate             No         300000
# 1950     1951                  0       Graduate            Yes         200000
# 2856     2857                  3   Not Graduate            Yes        8300000
# 3180     3181                  4       Graduate             No        3200000
# 3213     3214                  1   Not Graduate            Yes        4300000
# 3527     3528                  0       Graduate             No        1800000
# 4099     4100                  3       Graduate             No        8700000
#
#        loan_amount   loan_term   cibil_score   residential_assets_value  \
# 67        10100000          20           693                   200000.0
# 236        3500000           4           770                   700000.0
# 348        7000000           6           666                        0.0
# 395        3200000          10           584                        0.0
# 559         500000           6           885                        0.0
# 911        4800000           4           835                   500000.0
# 1446       1200000          18           747                   100000.0
# 1950        700000          10           587                        0.0
# 2856      31400000           6           674                  1000000.0
# 3180      12200000          14           683                        0.0
# 3213      16300000          14           792                   400000.0
# 3527       6900000          10           853                   900000.0
# 4099      31100000          16           760                   400000.0
#
#        commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 67                   1700000.0               5900000            1400000
# 236                        0.0               2000000             600000
# 348                  1200000.0               4300000            1400000
# 395                   200000.0               2100000             700000
# 559                        0.0                300000             200000
# 911                   100000.0               3300000             800000
# 1446                       0.0                700000             200000
# 1950                  100000.0                500000             100000
# 2856                 1600000.0              17200000            6100000
# 3180                 1100000.0               7500000            2900000
# 3213                  400000.0              10200000            4000000
# 3527                  400000.0               3700000            1700000
# 4099                 1800000.0              19300000            4800000
#
#       loan_status   total_collateral   loan_coll_ratio   loan_income_ratio
# 67       Rejected          9200000.0          1.097826            3.740741
# 236      Rejected          3300000.0          1.060606            3.888889
# 348      Rejected          6900000.0          1.014493            3.500000
# 395      Rejected          3000000.0          1.066667            4.000000
# 559      Rejected           500000.0          1.000000            2.500000
# 911      Rejected          4700000.0          1.021277            3.692308
# 1446     Rejected          1000000.0          1.200000            4.000000
# 1950     Rejected           700000.0          1.000000            3.500000
# 2856     Rejected         25900000.0          1.212355            3.783133
# 3180     Rejected         11500000.0          1.060870            3.812500
# 3213     Rejected         15000000.0          1.086667            3.790698
# 3527     Rejected          6700000.0          1.029851            3.833333
# 4099     Rejected         26300000.0          1.182510            3.574713

# %% [markdown]
# ##### Approvals Below 550 Credit Score

# %%
approved_df = df[df[' loan_status'] == ' Approved']
rejected_df = df[df[' loan_status'] == ' Rejected']

aprov_cibil_below_550 = approved_df[approved_df[' cibil_score'] < 550]
rejec_cibil_below_550 = rejected_df[rejected_df[' cibil_score'] < 550]
aprov_cibil_below_550 = aprov_cibil_below_550.drop(columns=[' loan_status', ' education', ' self_employed'])
rejec_cibil_below_550 = rejec_cibil_below_550.drop(columns=[' loan_status', ' education', ' self_employed'])

total_means = numerical_df.mean()
approved_means = aprov_cibil_below_550.mean()
rejected_means = rejec_cibil_below_550.mean()

approved_df / total_means
approved_means - rejected_means

# out of 1785 rows that were below a 550 credit score, only 185 were approved (10.36%)
# Out:
# loan_id                      5.091850e+01
#  no_of_dependents            3.150338e-02
#  income_annum               -1.936875e+05
#  loan_amount                 2.253062e+06
#  loan_term                  -8.613176e+00
#  cibil_score                -5.461334e+00
#  residential_assets_value    8.436149e+04
#  commercial_assets_value     2.325422e+05
#  luxury_assets_value        -4.745389e+05
#  bank_asset_value           -1.970895e+05
#  total_collateral           -3.547247e+05
#  loan_coll_ratio             8.155683e-02
#  loan_income_ratio           5.803107e-01
# dtype: float64

# %% [markdown]
# ##### Approved Vs. Rejected Loans

# %%
rejected_df = df[df[' loan_status'] == ' Rejected']
approved_df = df[df[' loan_status'] == ' Approved']

rejected_df = rejected_df.drop(columns=[' loan_status', ' education', ' self_employed'])
approved_df = approved_df.drop(columns=[' loan_status', ' education', ' self_employed'])

median_rejected = rejected_df.median()
median_approved = approved_df.median()

median_difference = median_approved - median_rejected

median_difference
# Out:
# loan_id                          60.500000
#  no_of_dependents                -0.500000
#  income_annum               -100000.000000
#  loan_amount                 100000.000000
#  loan_term                       -2.000000
#  cibil_score                    282.000000
#  residential_assets_value   -600000.000000
#  commercial_assets_value          0.000000
#  luxury_assets_value        -400000.000000
#  bank_asset_value           -100000.000000
#  total_collateral           -900000.000000
#  loan_coll_ratio                  0.016411
#  loan_income_ratio                0.174691
# dtype: float64

# %% [markdown]
# ##### High Collateral and Income Rejection

# %%
odd_point = df[(df[' loan_coll_ratio'] == 0.25) & (df[' loan_income_ratio'] == 1.5)]

odd_point
# Out:
#      loan_id   no_of_dependents      education  self_employed   income_annum  \
# 674      675                  0   Not Graduate             No         200000
#
#       loan_amount   loan_term   cibil_score   residential_assets_value  \
# 674        300000           6           472                   400000.0
#
#       commercial_assets_value   luxury_assets_value   bank_asset_value  \
# 674                  100000.0                700000                  0
#
#      loan_status   total_collateral   loan_coll_ratio   loan_income_ratio
# 674     Rejected          1200000.0              0.25                 1.5

# %% [markdown]
# ##### Zero Residential Assets

# %%
zero_res = numerical_df[numerical_df[' residential_assets_value'] == 0]
zero_res_means = zero_res.mean()
zero_res_means / total_means

# 89 rows with 0 residential assets value, 33 rejected, 56 approved
# Out:
# loan_id                      0.939027
#  no_of_dependents            1.031643
#  income_annum                0.589035
#  loan_amount                 0.606310
#  loan_term                   1.007094
#  cibil_score                 1.006700
#  residential_assets_value    0.000000
#  commercial_assets_value     0.666789
#  luxury_assets_value         0.557675
#  bank_asset_value            0.561730
# dtype: float64

# %% [markdown]
# ##### Zero Commercial Assets

# %%
zero_commercial = numerical_df[numerical_df[' commercial_assets_value'] == 0]

zero_commercial_means = zero_commercial.mean()
zc_cibil_avg = zero_commercial_means[" cibil_score"]
total_cibil_avg = total_means[" cibil_score"]

zero_commercial_means / total_means

# 124 rows of zero commercial assets, 73 are approved and 51 are rejected
# Out:
# loan_id                      0.947720
#  no_of_dependents            0.856516
#  income_annum                0.577286
#  loan_amount                 0.551542
#  loan_term                   0.994558
#  cibil_score                 1.017024
#  residential_assets_value    0.657758
#  commercial_assets_value     0.000000
#  luxury_assets_value         0.572933
#  bank_asset_value            0.546473
# dtype: float64

# %% [markdown]
# ##### Zero Bank Assets

# %%
zero_bank = df[df[' bank_asset_value'] == 0]

zero_bank_means = zero_bank.mean()
zc_cibil_avg = zero_bank_means[" cibil_score"]
total_cibil_avg = total_means[" cibil_score"]

zero_bank_means / total_means
# 8 rows with no bank assets, 3 were rejected, 5 were approved
# Out:
# C:\Users\Blake Dennett\AppData\Local\Temp\ipykernel_15660\1448357895.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   zero_bank_means = zero_bank.mean()
#  bank_asset_value            0.000000
#  cibil_score                 1.063655
#  commercial_assets_value     0.017790
#  income_annum                0.039533
#  loan_amount                 0.035517
#  loan_coll_ratio                  NaN
#  loan_income_ratio                NaN
#  loan_term                   1.055003
#  luxury_assets_value         0.033055
#  no_of_dependents            0.600309
#  residential_assets_value    0.049016
#  total_collateral                 NaN
# loan_id                      0.954274
# dtype: float64

# %% [markdown]
# ##### Correlation and P-value

# %%
for col in numerical_cols:
    correlation_coefficient, p_value = pearsonr(df[' cibil_score'], df[col])

    print(col)
    print("Pearson correlation coefficient:", correlation_coefficient)
    print("p-value:", p_value)
    print()
# Out:
# loan_id
# Pearson correlation coefficient: 0.016323386342227002
# p-value: 0.28629286440127394
#
#  no_of_dependents
# Pearson correlation coefficient: -0.009998469677432271
# p-value: 0.5136912487840075
#
#  income_annum
# Pearson correlation coefficient: -0.02303442169986018
# p-value: 0.1323826070379217
#
#  loan_amount
# Pearson correlation coefficient: -0.017034787023534382
# p-value: 0.2658086684763575
#
#  loan_term
# Pearson correlation coefficient: 0.007809878429870913
# p-value: 0.609955527226155
#
#  cibil_score
# Pearson correlation coefficient: 1.0
# p-value: 0.0
#
#  residential_assets_value
# Pearson correlation coefficient: -0.02414121331360626
# p-value: 0.11477332645819846
#
#  commercial_assets_value
# Pearson correlation coefficient: 0.002559122155018209
# p-value: 0.8672455979184643
#
#  luxury_assets_value
# Pearson correlation coefficient: -0.028617627946119942
# p-value: 0.06153354602205643
#
#  bank_asset_value
# Pearson correlation coefficient: -0.01547827134015627
# p-value: 0.31197944849413606
